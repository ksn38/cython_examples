# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import math
import matplotlib

# %% [markdown]
# ### cython source of mandelbrot_compl_cond:
# https://github.com/ksn38/cython_examples/blob/main/Imaginary_units_of_of_Mandelbrot_set/mandelbrot_compl_cond/mandelbrot_compl_cond.pyx

# %%
import mandelbrot_compl_cond

t1 = time.time()
resolution = 1440
#mb = mandelbrot.calc_mand(720, 2720, 0.0001, -0.745, 0.13, 2)
mb = mandelbrot_compl_cond.calc_mand(4, resolution, 50, scale=0.005, x=-1.5, y=0)
print ("time:", time.time() - t1)

fig, ax = plt.subplots()
fig.set_size_inches(2, 2)
fig.patch.set_visible(False)
ax.axis('off')
fig.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)

ax.imshow(mb.imag, cmap='gist_ncar')
plt.savefig(f'E:\\Temp\\{resolution}.png')
# Out:
# time: 0.7562308311462402

# %%
plt.plot(np.geomspace(0.001, 3, 10)[::-1])

# %% [markdown]
# ### Movie from imaginary units of of Mandelbrot set with changing scale

# %%
from mandelbrot_compl_cond import calc_mand

num = 0

for i in (np.geomspace(0.0000005, 3, 1800)[::-1]): #/20 + np.geomspace(0.001, 200, 1800)):   
    mb = calc_mand(4, 1440, 50, scale=i, x=-1.5, y=0)

    fig, ax = plt.subplots()
    fig.set_size_inches(20, 20)
    fig.patch.set_visible(False)
    ax.axis('off')
    fig.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
    
    my_cmap = matplotlib.colors.ListedColormap([i for i in ['#000000', '#000000', '#000000', '#000000', \
                                                            '#000000', '#000000', '#aeffac']*4], name='my_cmap')
    ax.imshow(mb.imag, cmap='gist_ncar')

    plt.savefig('E:\\Temp\\tmp/{:04d}.png'.format(num))
    plt.clf()
    
    num += 1
